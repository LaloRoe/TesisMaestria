# %% [markdown]
# # Ciclos límite

# %% [markdown]
# ## $$r'=r(1-r)$$

# %%
import numpy as np
import matplotlib.pyplot as plt

epsilon = 0.2

def f(r):
    y = r*(1-r**2)
    return y

def g(r):
    g = epsilon/2*r*(4-r**2)
    return g

r = np.linspace(0, 2.5, 30)

y = g(r)

fig, ax = plt.subplots(figsize = (25,8))
ax.set_title('r\'=r(1-r)')

ax.axhline(0, color='black', linestyle='--', linewidth=1)
ax.axhline(0, color='black', linestyle='--', linewidth=1)

for k in range(20):
    ax.annotate('', xy=(0.1*(k+1), 0), xytext=(0.1*k, 0),
            arrowprops=dict(facecolor='red', shrink=0.05, width=0.5, headwidth=10))  # Flecha en eje X
    
for k in range(5):
    ax.annotate('', xy=(2.5-0.1*(k+1), 0), xytext=(2.5-0.1*k, 0),
            arrowprops=dict(facecolor='red', shrink=0.05, width=0.5, headwidth=10))  # Flecha en eje X

ax.set_xlabel('r')
ax.set_ylabel('r\'')
ax.set_xlim(0, 2.5)
ax.set_ylim(-0.4, 0.4)
#ax.scatter(X, Y, color='0.5', s=1)
plt.plot(r, y, label=f'', color='green')

plt.legend()
#plt.grid(True)
plt.show()
# Out:
# /tmp/ipykernel_44502/856000324.py:39: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# # Teoría de promediación
